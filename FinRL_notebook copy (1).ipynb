# %% [markdown]
# # Content

# %% [markdown]
# # Prepping

# %% [markdown]
# ## Drive location

# %% [markdown]
# Followed cells are written to install `FinRL` which are adjusted for Vietnam stock market by our group

# %%
# %mkdir CS106-Vietnam-Stock-Trading

# %%
# %cd CS106-Vietnam-Stock-Trading

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install -q condacolab
# !pip install -r requirements.txt
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# !pip install pandas_market_calendars
# !pip install stable-baselines3

# %% [markdown]
# `!pip install` below has already install `vnquant` repo in it

# %% [markdown]
# ## Essential modules

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
import datetime
import itertools

# %matplotlib inline
from pprint import pprint

# %%
# directory
from __future__ import annotations

DATA_SAVE_DIR = "datasets"
TRAINED_MODEL_DIR = "trained_models"
TENSORBOARD_LOG_DIR = "tensorboard_log"
RESULTS_DIR = "results"

# date format: '%Y-%m-%d'
# date format: '%Y-%m-%d'
TRAIN_START_DATE = '2014-01-01'
TRAIN_END_DATE = '2020-09-30'
TEST_START_DATE = '2020-09-30'
TEST_END_DATE = '2025-06-01'


# stockstats technical indicator column names
# check https://pypi.org/project/stockstats/ for different names
INDICATORS = ['macd',
               'rsi_30',
               'cci_30',
               'dx_30']

# Model Parameters
A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.01, "learning_rate": 0.0007}
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 64,
}
DDPG_PARAMS = None 
TD3_PARAMS = None 
SAC_PARAMS = None
ERL_PARAMS = None

RLlib_PARAMS = None

# %%
import os
if not os.path.exists("./" + DATA_SAVE_DIR):
    os.makedirs("./" + DATA_SAVE_DIR)
if not os.path.exists("./" + TRAINED_MODEL_DIR):
    os.makedirs("./" + TRAINED_MODEL_DIR)
if not os.path.exists("./" + TENSORBOARD_LOG_DIR):
    os.makedirs("./" + TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + RESULTS_DIR):
    os.makedirs("./" + RESULTS_DIR)

# %% [markdown]
# # A. Problem definition

# %% [markdown]
# This problem is to design an automated trading solution for single/multiple stock trading. We model the stock trading process as a **Markov Decision Process (MDP)**. We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * ***Action:*** The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: $a ∈ {−1, 0, 1}$, where $−1, 0, 1$ represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space ${−k, ..., −1, 0, 1, ..., k}$, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * ***Reward function:*** `r(s, a, s′)` is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., $r(s, a, s′) = v′ − v$, where $v'$ and $v$ represent the portfolio
# values at state s′ and s, respectively
#
# * ***State:*** The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * ***Environment:*** VN30 for multiple stock and VNM for single stock
#
# The data is provided through [**vnquant**](https://github.com/ThangDuong59/vnquant) which is adjusted by us for suitable to FinRL
#
# And this repo is based on [**FinRL: A Deep Reinforcement Learning Framework for Quantitative Finance**](https://github.com/AI4Finance-LLC/FinRL#finrl-a-deep-reinforcement-learning-framework-for-quantitative-finance----)

# %%
def data_split(df, start, end, target_date_col="date"):
    """
    split the dataset into training or testing using date
    :param data: (df) pandas dataframe, start, end
    :return: (df) pandas dataframe
    """
    data = df[(df[target_date_col] >= start) & (df[target_date_col] < end)]
    data = data.sort_values([target_date_col, "tic"], ignore_index=True)
    data.index = data[target_date_col].factorize()[0]
    return data
from __future__ import annotations

from typing import List

import gymnasium as gym
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from gymnasium import spaces
from gymnasium.utils import seeding
from stable_baselines3.common.vec_env import DummyVecEnv

matplotlib.use("Agg")

# from stable_baselines3.common.logger import Logger, KVWriter, CSVOutputFormat


class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""

    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df: pd.DataFrame,
        stock_dim: int,
        hmax: int,
        initial_amount: int,
        num_stock_shares: list[int],
        buy_cost_pct: list[float],
        sell_cost_pct: list[float],
        reward_scaling: float,
        state_space: int,
        action_space: int,
        tech_indicator_list: list[str],
        turbulence_threshold=None,
        risk_indicator_col="turbulence",
        make_plots: bool = False,
        print_verbosity=10,
        day=0,
        initial=True,
        previous_state=[],
        model_name="",
        mode="",
        iteration="",
    ):
        self.day = day
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.num_stock_shares = num_stock_shares
        self.initial_amount = initial_amount  # get the initial cash
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.action_space,))
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.state_space,)
        )
        self.data = self.df.loc[self.day, :]
        self.terminal = False
        self.make_plots = make_plots
        self.print_verbosity = print_verbosity
        self.turbulence_threshold = turbulence_threshold
        self.risk_indicator_col = risk_indicator_col
        self.initial = initial
        self.previous_state = previous_state
        self.model_name = model_name
        self.mode = mode
        self.iteration = iteration
        # initalize state
        self.state = self._initiate_state()

        # initialize reward
        self.reward = 0
        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.episode = 0
        # memorize all the total balance change
        self.asset_memory = [
            self.initial_amount
            + np.sum(
                np.array(self.num_stock_shares)
                * np.array(self.state[1 : 1 + self.stock_dim])
            )
        ]  # the initial total asset is calculated by cash + sum (num_share_stock_i * price_stock_i)
        self.rewards_memory = []
        self.actions_memory = []
        self.state_memory = (
            []
        )  # we need sometimes to preserve the state in the middle of trading process
        self.date_memory = [self._get_date()]
        #         self.logger = Logger('results',[CSVOutputFormat])
        # self.reset()
        self._seed()

    def _sell_stock(self, index, action):
        def _do_sell_normal():
            if (
                self.state[index + 2 * self.stock_dim + 1] != True
            ):  # check if the stock is able to sell, for simlicity we just add it in techical index
                # if self.state[index + 1] > 0: # if we use price<0 to denote a stock is unable to trade in that day, the total asset calculation may be wrong for the price is unreasonable
                # Sell only if the price is > 0 (no missing data in this particular date)
                # perform sell action based on the sign of the action
                if self.state[index + self.stock_dim + 1] > 0:
                    # Sell only if current asset is > 0
                    sell_num_shares = min(
                        abs(action), self.state[index + self.stock_dim + 1]
                    )
                    sell_amount = (
                        self.state[index + 1]
                        * sell_num_shares
                        * (1 - self.sell_cost_pct[index])
                    )
                    # update balance
                    self.state[0] += sell_amount

                    self.state[index + self.stock_dim + 1] -= sell_num_shares
                    self.cost += (
                        self.state[index + 1]
                        * sell_num_shares
                        * self.sell_cost_pct[index]
                    )
                    self.trades += 1
                else:
                    sell_num_shares = 0
            else:
                sell_num_shares = 0

            return sell_num_shares

        # perform sell action based on the sign of the action
        if self.turbulence_threshold is not None:
            if self.turbulence >= self.turbulence_threshold:
                if self.state[index + 1] > 0:
                    # Sell only if the price is > 0 (no missing data in this particular date)
                    # if turbulence goes over threshold, just clear out all positions
                    if self.state[index + self.stock_dim + 1] > 0:
                        # Sell only if current asset is > 0
                        sell_num_shares = self.state[index + self.stock_dim + 1]
                        sell_amount = (
                            self.state[index + 1]
                            * sell_num_shares
                            * (1 - self.sell_cost_pct[index])
                        )
                        # update balance
                        self.state[0] += sell_amount
                        self.state[index + self.stock_dim + 1] = 0
                        self.cost += (
                            self.state[index + 1]
                            * sell_num_shares
                            * self.sell_cost_pct[index]
                        )
                        self.trades += 1
                    else:
                        sell_num_shares = 0
                else:
                    sell_num_shares = 0
            else:
                sell_num_shares = _do_sell_normal()
        else:
            sell_num_shares = _do_sell_normal()

        return sell_num_shares

    def _buy_stock(self, index, action):
        def _do_buy():
            if (
                self.state[index + 2 * self.stock_dim + 1] != True
            ):  # check if the stock is able to buy
                # if self.state[index + 1] >0:
                # Buy only if the price is > 0 (no missing data in this particular date)
                available_amount = self.state[0] // (
                    self.state[index + 1] * (1 + self.buy_cost_pct[index])
                )  # when buying stocks, we should consider the cost of trading when calculating available_amount, or we may be have cash<0
                # print('available_amount:{}'.format(available_amount))

                # update balance
                buy_num_shares = min(available_amount, action)
                buy_amount = (
                    self.state[index + 1]
                    * buy_num_shares
                    * (1 + self.buy_cost_pct[index])
                )
                self.state[0] -= buy_amount

                self.state[index + self.stock_dim + 1] += buy_num_shares

                self.cost += (
                    self.state[index + 1] * buy_num_shares * self.buy_cost_pct[index]
                )
                self.trades += 1
            else:
                buy_num_shares = 0

            return buy_num_shares

        # perform buy action based on the sign of the action
        if self.turbulence_threshold is None:
            buy_num_shares = _do_buy()
        else:
            if self.turbulence < self.turbulence_threshold:
                buy_num_shares = _do_buy()
            else:
                buy_num_shares = 0
                pass

        return buy_num_shares

    def _make_plot(self):
        plt.plot(self.asset_memory, "r")
        plt.savefig(f"results/account_value_trade_{self.episode}.png")
        plt.close()

    def step(self, actions):
        self.terminal = self.day >= len(self.df.index.unique()) - 1
        if self.terminal:
            # print(f"Episode: {self.episode}")
            if self.make_plots:
                self._make_plot()
            end_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            df_total_value = pd.DataFrame(self.asset_memory)
            tot_reward = (
                self.state[0]
                + sum(
                    np.array(self.state[1 : (self.stock_dim + 1)])
                    * np.array(
                        self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)]
                    )
                )
                - self.asset_memory[0]
            )  # initial_amount is only cash part of our initial asset
            df_total_value.columns = ["account_value"]
            df_total_value["date"] = self.date_memory
            df_total_value["daily_return"] = df_total_value["account_value"].pct_change(
                1
            )
            if df_total_value["daily_return"].std() != 0:
                sharpe = (
                    (252**0.5)
                    * df_total_value["daily_return"].mean()
                    / df_total_value["daily_return"].std()
                )
            df_rewards = pd.DataFrame(self.rewards_memory)
            df_rewards.columns = ["account_rewards"]
            df_rewards["date"] = self.date_memory[:-1]
            if self.episode % self.print_verbosity == 0:
                print(f"day: {self.day}, episode: {self.episode}")
                print(f"begin_total_asset: {self.asset_memory[0]:0.2f}")
                print(f"end_total_asset: {end_total_asset:0.2f}")
                print(f"total_reward: {tot_reward:0.2f}")
                print(f"total_cost: {self.cost:0.2f}")
                print(f"total_trades: {self.trades}")
                if df_total_value["daily_return"].std() != 0:
                    print(f"Sharpe: {sharpe:0.3f}")
                print("=================================")

            if (self.model_name != "") and (self.mode != ""):
                df_actions = self.save_action_memory()
                df_actions.to_csv(
                    "results/actions_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    )
                )
                df_total_value.to_csv(
                    "results/account_value_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                df_rewards.to_csv(
                    "results/account_rewards_{}_{}_{}.csv".format(
                        self.mode, self.model_name, self.iteration
                    ),
                    index=False,
                )
                plt.plot(self.asset_memory, "r")
                plt.savefig(
                    "results/account_value_{}_{}_{}.png".format(
                        self.mode, self.model_name, self.iteration
                    )
                )
                plt.close()

            # Add outputs to logger interface
            # logger.record("environment/portfolio_value", end_total_asset)
            # logger.record("environment/total_reward", tot_reward)
            # logger.record("environment/total_reward_pct", (tot_reward / (end_total_asset - tot_reward)) * 100)
            # logger.record("environment/total_cost", self.cost)
            # logger.record("environment/total_trades", self.trades)

            return self.state, self.reward, self.terminal, False, {}

        else:
            actions = actions * self.hmax  # actions initially is scaled between 0 to 1
            actions = actions.astype(
                int
            )  # convert into integer because we can't by fraction of shares
            if self.turbulence_threshold is not None:
                if self.turbulence >= self.turbulence_threshold:
                    actions = np.array([-self.hmax] * self.stock_dim)
            begin_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            # print("begin_total_asset:{}".format(begin_total_asset))

            argsort_actions = np.argsort(actions)
            sell_index = argsort_actions[: np.where(actions < 0)[0].shape[0]]
            buy_index = argsort_actions[::-1][: np.where(actions > 0)[0].shape[0]]

            for index in sell_index:
                # print(f"Num shares before: {self.state[index+self.stock_dim+1]}")
                # print(f'take sell action before : {actions[index]}')
                actions[index] = self._sell_stock(index, actions[index]) * (-1)
                # print(f'take sell action after : {actions[index]}')
                # print(f"Num shares after: {self.state[index+self.stock_dim+1]}")

            for index in buy_index:
                # print('take buy action: {}'.format(actions[index]))
                actions[index] = self._buy_stock(index, actions[index])

            self.actions_memory.append(actions)

            # state: s -> s+1
            self.day += 1
            self.data = self.df.loc[self.day, :]
            if self.turbulence_threshold is not None:
                if len(self.df.tic.unique()) == 1:
                    self.turbulence = self.data[self.risk_indicator_col]
                elif len(self.df.tic.unique()) > 1:
                    self.turbulence = self.data[self.risk_indicator_col].values[0]
            self.state = self._update_state()

            end_total_asset = self.state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
            )
            self.asset_memory.append(end_total_asset)
            self.date_memory.append(self._get_date())
            self.reward = end_total_asset - begin_total_asset
            self.rewards_memory.append(self.reward)
            self.reward = self.reward * self.reward_scaling
            self.state_memory.append(
                self.state
            )  # add current state in state_recorder for each step

        return self.state, self.reward, self.terminal, False, {}

    def reset(
        self,
        *,
        seed=None,
        options=None,
    ):
        # initiate state
        self.day = 0
        self.data = self.df.loc[self.day, :]
        self.state = self._initiate_state()

        if self.initial:
            self.asset_memory = [
                self.initial_amount
                + np.sum(
                    np.array(self.num_stock_shares)
                    * np.array(self.state[1 : 1 + self.stock_dim])
                )
            ]
        else:
            previous_total_asset = self.previous_state[0] + sum(
                np.array(self.state[1 : (self.stock_dim + 1)])
                * np.array(
                    self.previous_state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)]
                )
            )
            self.asset_memory = [previous_total_asset]

        self.turbulence = 0
        self.cost = 0
        self.trades = 0
        self.terminal = False
        # self.iteration=self.iteration
        self.rewards_memory = []
        self.actions_memory = []
        self.date_memory = [self._get_date()]

        self.episode += 1

        return self.state, {}

    def render(self, mode="human", close=False):
        return self.state

    def _initiate_state(self):
        if self.initial:
            # For Initial State
            if len(self.df.tic.unique()) > 1:
                # for multiple stock
                state = (
                    [self.initial_amount]
                    + self.data.close.values.tolist()
                    + self.num_stock_shares
                    + sum(
                        (
                            self.data[tech].values.tolist()
                            for tech in self.tech_indicator_list
                        ),
                        [],
                    )
                )  # append initial stocks_share to initial state, instead of all zero
            else:
                # for single stock
                state = (
                    [self.initial_amount]
                    + [self.data.close]
                    + [0] * self.stock_dim
                    + sum(([self.data[tech]] for tech in self.tech_indicator_list), [])
                )
        else:
            # Using Previous State
            if len(self.df.tic.unique()) > 1:
                # for multiple stock
                state = (
                    [self.previous_state[0]]
                    + self.data.close.values.tolist()
                    + self.previous_state[
                        (self.stock_dim + 1) : (self.stock_dim * 2 + 1)
                    ]
                    + sum(
                        (
                            self.data[tech].values.tolist()
                            for tech in self.tech_indicator_list
                        ),
                        [],
                    )
                )
            else:
                # for single stock
                state = (
                    [self.previous_state[0]]
                    + [self.data.close]
                    + self.previous_state[
                        (self.stock_dim + 1) : (self.stock_dim * 2 + 1)
                    ]
                    + sum(([self.data[tech]] for tech in self.tech_indicator_list), [])
                )
        return state

    def _update_state(self):
        if len(self.df.tic.unique()) > 1:
            # for multiple stock
            state = (
                [self.state[0]]
                + self.data.close.values.tolist()
                + list(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
                + sum(
                    (
                        self.data[tech].values.tolist()
                        for tech in self.tech_indicator_list
                    ),
                    [],
                )
            )

        else:
            # for single stock
            state = (
                [self.state[0]]
                + [self.data.close]
                + list(self.state[(self.stock_dim + 1) : (self.stock_dim * 2 + 1)])
                + sum(([self.data[tech]] for tech in self.tech_indicator_list), [])
            )

        return state

    def _get_date(self):
        if len(self.df.tic.unique()) > 1:
            date = self.data.date.unique()[0]
        else:
            date = self.data.date
        return date

    # add save_state_memory to preserve state in the trading process
    def save_state_memory(self):
        if len(self.df.tic.unique()) > 1:
            # date and close price length must match actions length
            date_list = self.date_memory[:-1]
            df_date = pd.DataFrame(date_list)
            df_date.columns = ["date"]

            state_list = self.state_memory
            df_states = pd.DataFrame(
                state_list,
                columns=[
                    "cash",
                    "Bitcoin_price",
                    "Gold_price",
                    "Bitcoin_num",
                    "Gold_num",
                    "Bitcoin_Disable",
                    "Gold_Disable",
                ],
            )
            df_states.index = df_date.date
            # df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        else:
            date_list = self.date_memory[:-1]
            state_list = self.state_memory
            df_states = pd.DataFrame({"date": date_list, "states": state_list})
        # print(df_states)
        return df_states

    def save_asset_memory(self):
        date_list = self.date_memory
        asset_list = self.asset_memory
        # print(len(date_list))
        # print(len(asset_list))
        df_account_value = pd.DataFrame(
            {"date": date_list, "account_value": asset_list}
        )
        return df_account_value

    def save_action_memory(self):
        if len(self.df.tic.unique()) > 1:
            # date and close price length must match actions length
            date_list = self.date_memory[:-1]
            df_date = pd.DataFrame(date_list)
            df_date.columns = ["date"]

            action_list = self.actions_memory
            df_actions = pd.DataFrame(action_list)
            df_actions.columns = self.data.tic.values
            df_actions.index = df_date.date
            # df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        else:
            date_list = self.date_memory[:-1]
            action_list = self.actions_memory
            df_actions = pd.DataFrame({"date": date_list, "actions": action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
# %matplotlib inline
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
# Out:
# c:\Users\phuon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyfolio\pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# ## Data

# %% [markdown]
# `vnquant`, written by Pham Dinh Khanh, is a package allow you to crawl data through **VNDIRECT** API.
#
# The reason we don't use default crawler is **Yahoo Downloader** is just able to download some common stock in Vietnam.

# %% [markdown]
# -----
# class vnquantDownloader:
#     Provides methods for retrieving daily stock data from
#     VNDirect
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from py)
#         end_date : str
#             end date of the data (modified from py)
#         ticker_list : list
#             a list of stock tickers (modified from py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from VNDirect API
#         Returns
#         -------
#         `pd.DataFrame`
#             7 columns: A date, open, high, low, close, volume and tick symbol
#             for the specified stock ticker
#         """

# %% [markdown]
# Users can choose their own ticker

# %%
# !pip install -U vnstock

# %%
from vnstock import Vnstock

# Lấy dữ liệu cổ phiếu ACB
stock = Vnstock().stock(symbol='ACB', source='VCI')

# %%
VN_30_TICKER_vnstock = stock.listing.symbols_by_group('VN30').tolist()
print(VN_30_TICKER_vnstock)
# Out:
# ['ACB', 'BCM', 'BID', 'BVH', 'CTG', 'FPT', 'GAS', 'GVR', 'HDB', 'HPG', 'LPB', 'MBB', 'MSN', 'MWG', 'PLX', 'SAB', 'SHB', 'SSB', 'SSI', 'STB', 'TCB', 'TPB', 'VCB', 'VHM', 'VIB', 'VIC', 'VJC', 'VNM', 'VPB', 'VRE']

# %%
# prompt: "df = stock.quote.history(start='2024-01-01', end='2025-03-19', interval='1D')
# df" I want the df here is df of the history of all 30 stock in the list vn_30_ticker_vnstock above

import pandas as pd
stock = Vnstock()
all_vn30_data = []

for ticker in VN_30_TICKER_vnstock:
    print(f"Fetching data for {ticker}")
    try:
        df_ticker = stock.stock(symbol=ticker, source='VCI').quote.history(start=TRAIN_START_DATE, end=TEST_END_DATE, interval='1D')
        df_ticker['tic'] = ticker  # Add a ticker column to identify the stock
        all_vn30_data.append(df_ticker)
    except Exception as e:
        print(f"Could not fetch data for {ticker}: {e}")

df = pd.concat(all_vn30_data, ignore_index=True)
print(df.head())
print(df.tail())
# Out:
# Fetching data for ACB
# Could not fetch data for ACB: name 'TRAIN_START_DATE' is not defined
# Fetching data for BCM
# Could not fetch data for BCM: name 'TRAIN_START_DATE' is not defined
# Fetching data for BID
# Could not fetch data for BID: name 'TRAIN_START_DATE' is not defined
# Fetching data for BVH
# Could not fetch data for BVH: name 'TRAIN_START_DATE' is not defined
# Fetching data for CTG
# Could not fetch data for CTG: name 'TRAIN_START_DATE' is not defined
# Fetching data for FPT
# Could not fetch data for FPT: name 'TRAIN_START_DATE' is not defined
# Fetching data for GAS
# Could not fetch data for GAS: name 'TRAIN_START_DATE' is not defined
# Fetching data for GVR
# Could not fetch data for GVR: name 'TRAIN_START_DATE' is not defined
# Fetching data for HDB
# Could not fetch data for HDB: name 'TRAIN_START_DATE' is not defined
# Fetching data for HPG
# Could not fetch data for HPG: name 'TRAIN_START_DATE' is not defined
# Fetching data for LPB
# Could not fetch data for LPB: name 'TRAIN_START_DATE' is not defined
# Fetching data for MBB
# Could not fetch data for MBB: name 'TRAIN_START_DATE' is not defined
# Fetching data for MSN
# Could not fetch data for MSN: name 'TRAIN_START_DATE' is not defined
# Fetching data for MWG
# Could not fetch data for MWG: name 'TRAIN_START_DATE' is not defined
# Fetching data for PLX
# Could not fetch data for PLX: name 'TRAIN_START_DATE' is not defined
# Fetching data for SAB
# Could not fetch data for SAB: name 'TRAIN_START_DATE' is not defined
# Fetching data for SHB
# Could not fetch data for SHB: name 'TRAIN_START_DATE' is not defined
# Fetching data for SSB
# Could not fetch data for SSB: name 'TRAIN_START_DATE' is not defined
# Fetching data for SSI
# Could not fetch data for SSI: name 'TRAIN_START_DATE' is not defined
# Fetching data for STB
# Could not fetch data for STB: name 'TRAIN_START_DATE' is not defined
# Fetching data for TCB
# Could not fetch data for TCB: name 'TRAIN_START_DATE' is not defined
# Fetching data for TPB
# Could not fetch data for TPB: name 'TRAIN_START_DATE' is not defined
# Fetching data for VCB
# Could not fetch data for VCB: name 'TRAIN_START_DATE' is not defined
# Fetching data for VHM
# Could not fetch data for VHM: name 'TRAIN_START_DATE' is not defined
# Fetching data for VIB
# Could not fetch data for VIB: name 'TRAIN_START_DATE' is not defined
# Fetching data for VIC
# Could not fetch data for VIC: name 'TRAIN_START_DATE' is not defined
# Fetching data for VJC
# Could not fetch data for VJC: name 'TRAIN_START_DATE' is not defined
# Fetching data for VNM
# Could not fetch data for VNM: name 'TRAIN_START_DATE' is not defined
# Fetching data for VPB
# Could not fetch data for VPB: name 'TRAIN_START_DATE' is not defined
# Fetching data for VRE
# Could not fetch data for VRE: name 'TRAIN_START_DATE' is not defined
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 17
#      14     except Exception as e:
#      15         print(f"Could not fetch data for {ticker}: {e}")
# ---> 17 df = pd.concat(all_vn30_data, ignore_index=True)
#      18 print(df.head())
#      19 print(df.tail())
#
# File c:\Users\phuon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File c:\Users\phuon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File c:\Users\phuon\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
df.tail(20)
# Out:
#             time   open   high    low  close    volume  tic
# 72007 2025-05-05  23.55  24.90  23.45  24.90  13894100  VRE
# 72008 2025-05-06  24.95  24.95  24.40  24.90  14299500  VRE
# 72009 2025-05-07  24.85  24.95  24.55  24.90  10299900  VRE
# 72010 2025-05-08  24.80  25.60  24.65  25.00   8070800  VRE
# 72011 2025-05-09  24.80  25.10  24.70  25.00   8062500  VRE
# 72012 2025-05-12  25.00  25.60  24.85  25.50   6970400  VRE
# 72013 2025-05-13  25.50  25.50  24.75  25.40  11591700  VRE
# 72014 2025-05-14  24.95  25.50  24.35  24.70  12161100  VRE
# 72015 2025-05-15  24.50  24.50  23.00  24.15  28934800  VRE
# 72016 2025-05-16  24.10  24.55  23.60  24.50  13251800  VRE
# 72017 2025-05-19  24.50  25.20  24.25  24.75  10039000  VRE
# 72018 2025-05-20  24.75  25.90  24.70  25.80  15404600  VRE
# 72019 2025-05-21  26.20  26.30  25.35  25.75  10755400  VRE
# 72020 2025-05-22  25.65  26.05  25.10  25.35  13504200  VRE
# 72021 2025-05-23  25.30  26.10  25.15  25.65  10961400  VRE
# 72022 2025-05-26  25.60  25.65  24.50  25.50   8734200  VRE
# 72023 2025-05-27  25.50  25.75  25.25  25.30  11529600  VRE
# 72024 2025-05-28  25.55  26.80  25.35  26.70  16719800  VRE
# 72025 2025-05-29  26.80  27.70  26.80  27.65  16071500  VRE
# 72026 2025-05-30  27.65  27.70  27.00  27.50   9128900  VRE

# %%
df.head(5)
# Out:
#         time  open  high   low  close  volume  tic
# 0 2014-01-02  2.29  2.29  2.28   2.29  146982  ACB
# 1 2014-01-03  2.29  2.31  2.28   2.31   98656  ACB
# 2 2014-01-06  2.28  2.31  2.28   2.29  190009  ACB
# 3 2014-01-07  2.31  2.35  2.29   2.32  152905  ACB
# 4 2014-01-08  2.32  2.32  2.29   2.31   58852  ACB

# %%
# prompt: rename column time to date, rearrange the column Price (the first index column)	date	close	high	low	open	volume	tic

df = df.rename(columns={'time': 'date'})
cols = ['date', 'close', 'high', 'low', 'open', 'volume', 'tic']
df = df[cols]

# %% [markdown]
# ### Download data

# %% [markdown]
# Save data to `.csv` file

# %%
now = datetime.datetime.now().strftime("%Y%m%d-%Hh%M")
df.to_csv("./" + DATA_SAVE_DIR + "/" + now + ".csv")

# %%
df.sort_values(['date','tic']).head(5)
# Out:
#             date  close   high    low   open  volume  tic
# 0     2014-01-02   2.29   2.29   2.28   2.29  146982  ACB
# 7477  2014-01-02  29.05  29.36  28.98  29.05   87000  BVH
# 10321 2014-01-02   9.01   9.07   8.96   9.07  156420  CTG
# 13165 2014-01-02   6.45   6.50   6.42   6.48  207470  FPT
# 16009 2014-01-02  31.69  31.69  31.21  31.69  229950  GAS

# %%
print(len(df["date"].unique()))
# Out:
# 2844

# %%
print(len(df["tic"].unique()))
# Out:
# 30

# %% [markdown]
# ## Data adjustment

# %% [markdown]
# -----
# class FeatureEngineer:
#     Provides methods for preprocessing the stock price data
#
#     Attributes
#     ----------
#         use_technical_indicator : boolean
#             we technical indicator or not
#         tech_indicator_list : list
#             a list of technical indicator names (modified from py)
#         use_turbulence : boolean
#             use turbulence index or not
#         user_defined_feature:boolean
#             user user defined features or not
#
#     Methods
#     -------
#     preprocess_data()
#         main method to do the feature engineering

# %%
INDICATORS = ['macd',
               'rsi_30',
               'cci_30',
               'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#             date   close    high     low    open   volume  tic      macd  \
# 7827  2016-08-22   35.85   36.39   35.30   35.30   462840  GAS  0.380361
# 1814  2014-08-18    9.14    9.23    8.88    8.96  1735290  FPT  0.113936
# 20259 2020-10-09   51.31   51.80   51.18   51.80   438960  GAS  0.296113
# 27073 2023-01-16   26.85   26.85   25.86   26.04  5350309  CTG  0.633225
# 33902 2025-05-06  109.70  111.00  108.60  108.60  5686200  FPT -4.116960
#
#           rsi_30      cci_30      dx_30  turbulence
# 7827   58.572963  111.716008  26.338984   11.801690
# 1814   57.921743  126.304802  44.783787    0.000000
# 20259  55.386313  112.693247  27.120394   17.741251
# 27073  59.910322  187.196334  22.494205    6.297456
# 33902  37.921354  -62.147696  38.381551   15.008609

# %%
processed.head(5)
# Out:
#         date  close   high    low   open  volume  tic  macd  rsi_30  \
# 0 2014-01-02  29.05  29.36  28.98  29.05   87000  BVH   0.0   100.0
# 1 2014-01-02   9.01   9.07   8.96   9.07  156420  CTG   0.0   100.0
# 2 2014-01-02   6.45   6.50   6.42   6.48  207470  FPT   0.0   100.0
# 3 2014-01-02  31.69  31.69  31.21  31.69  229950  GAS   0.0   100.0
# 4 2014-01-02   2.71   2.74   2.70   2.74  276250  HPG   0.0   100.0
#
#       cci_30  dx_30  turbulence
# 0 -66.666667  100.0         0.0
# 1 -66.666667  100.0         0.0
# 2 -66.666667  100.0         0.0
# 3 -66.666667  100.0         0.0
# 4 -66.666667  100.0         0.0

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 12, State Space: 73

# %% [markdown]
# # B. Implementation

# %% [markdown]
# ## Env initial params

# %%
# env_kwargs = {
#     "hmax": 100,
#     "initial_amount": 1000000,
#     "buy_cost_pct": 0.001,
#     "sell_cost_pct": 0.001,
#     "state_space": state_space,
#     "stock_dim": stock_dimension,
#     "tech_indicator_list": INDICATORS,
#     "action_space": stock_dimension,
#     "reward_scaling": 1e-4,
#     "print_verbosity": 5

# }

ensemble_env_kwargs = {
    "hmax": 50000, 
    "initial_amount": 100000000,
    "buy_cost_pct": 0.0015,
    "sell_cost_pct": 0.0015,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "print_verbosity": 10
}

trading_env_kwargs = {
    "hmax": 50000, 
    "initial_amount": 100000000,
    "buy_cost_pct": [0.0015] * stock_dimension,
    "sell_cost_pct": [0.0015] * stock_dimension,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "print_verbosity": 10,
    "num_stock_shares": [0] * stock_dimension
}

# %% [markdown]
# ## Env initialization

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window,
                 validation_window=validation_window,
                 **ensemble_env_kwargs)

# %%
from datetime import datetime, timedelta

train_start_dt = datetime.strptime(TRAIN_START_DATE, "%Y-%m-%d")
result_start_date = train_start_dt + timedelta(days=validation_window)
result_start_date_str = result_start_date.strftime("%Y-%m-%d")

train_end_dt = datetime.strptime(TRAIN_END_DATE, "%Y-%m-%d")
result_end_date = train_end_dt + timedelta(days=validation_window)
result_end_date_str = result_end_date.strftime("%Y-%m-%d")

train = data_split(processed, result_start_date_str, result_end_date_str)
trade = data_split(processed, TEST_START_DATE, TEST_END_DATE)

# Fixed: Create the trading environment properly
e_train_gym = StockTradingEnv(
    df=train, 
    **trading_env_kwargs
)
env_train, _ = e_train_gym.get_sb_env()

agent = DRLAgent(env=env_train)

# %% [markdown]
# ## Model training

# %%
A2C_model_kwargs = {"n_steps": 5, "ent_coef": 0.01, "learning_rate": 0.0007}
PPO_model_kwargs = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 64,
}
DDPG_model_kwargs = None
TD3_model_kwargs = None
SAC_model_kwargs = None

timesteps_dict = {
    'a2c': 100_000,
    'ppo': 100_000,
    'ddpg': None
}

# %% [markdown]
# ### A2C model

# %%
print("==============Model Training===========")

model_a2c = agent.get_model("a2c")
trained_a2c = agent.train_model(
    model=model_a2c, tb_log_name="a2c", total_timesteps=timesteps_dict['a2c']
)

# %%
print("==============Model Training===========")
model_ppo = agent.get_model("ppo")
trained_ppo = agent.train_model(
    model=model_ppo, tb_log_name="ppo", total_timesteps=timesteps_dict['ppo'])
# Out:
# ==============Model Training===========
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging Error: name 'statistics' is not defined
# -----------------------------------
# | time/              |            |
# |    fps             | 313        |
# |    iterations      | 1          |
# |    time_elapsed    | 6          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | -21.227919 |
# |    reward_max      | None       |
# |    reward_mean     | None       |
# |    reward_min      | None       |
# -----------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008636259 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17         |
# |    explained_variance   | -0.000106   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.54e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0137     |
# |    reward               | -102.78409  |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1           |
# |    value_loss           | 2.36e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008725807 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17         |
# |    explained_variance   | -0.000307   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.9e+05     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0149     |
# |    reward               | -202.16713  |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1           |
# |    value_loss           | 2.86e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 4           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010430563 |
# |    clip_fraction        | 0.0852      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17         |
# |    explained_variance   | 7.03e-05    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.25e+05    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0108     |
# |    reward               | 19.144236   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 0.999       |
# |    value_loss           | 5.24e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 5           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008012347 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17         |
# |    explained_variance   | 0.000134    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.54e+04    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0147     |
# |    reward               | 19.970604   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 0.999       |
# |    value_loss           | 3.21e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 6           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010976787 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17         |
# |    explained_variance   | -0.000747   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.13e+05    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.017      |
# |    reward               | -52.34555   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1           |
# |    value_loss           | 2.71e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 7           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010082959 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17         |
# |    explained_variance   | 0.000476    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.88e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0177     |
# |    reward               | -49.07117   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1           |
# |    value_loss           | 2.61e+05    |
# -----------------------------------------
# day: 1688, episode: 70
# begin_total_asset: 100000000.00
# end_total_asset: 181950120.10
# total_reward: 81950120.10
# total_cost: 23211443.57
# total_trades: 19163
# Sharpe: 0.554
# =================================
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 8           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011042599 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17         |
# |    explained_variance   | -0.000632   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.29e+05    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0147     |
# |    reward               | -71.840164  |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1           |
# |    value_loss           | 2.45e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 9           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008995147 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.1       |
# |    explained_variance   | -3.72e-05   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.12e+05    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0135     |
# |    reward               | 234.62381   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1           |
# |    value_loss           | 4.54e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 10          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009032844 |
# |    clip_fraction        | 0.0925      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.1       |
# |    explained_variance   | 6.61e-05    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.55e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0191     |
# |    reward               | 41.04757    |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.01        |
# |    value_loss           | 2.12e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 11          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008974521 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.2       |
# |    explained_variance   | -0.000523   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.62e+05    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0194     |
# |    reward               | -36.77641   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.01        |
# |    value_loss           | 3.65e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 12          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008743649 |
# |    clip_fraction        | 0.0822      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.2       |
# |    explained_variance   | 0.00161     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.26e+05    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0193     |
# |    reward               | 276.26028   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.01        |
# |    value_loss           | 3.28e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 13          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008594429 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.2       |
# |    explained_variance   | -0.000497   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.38e+04    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0173     |
# |    reward               | 99.668236   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.01        |
# |    value_loss           | 1.97e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 14          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011033684 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.2       |
# |    explained_variance   | 0.0012      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.33e+05    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0217     |
# |    reward               | 87.83372    |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.02        |
# |    value_loss           | 3.06e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 15          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009874955 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.2       |
# |    explained_variance   | 0.00514     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.01e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0212     |
# |    reward               | 7.4701037   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.01        |
# |    value_loss           | 1.46e+05    |
# -----------------------------------------
# day: 1688, episode: 80
# begin_total_asset: 100000000.00
# end_total_asset: 93531466.15
# total_reward: -6468533.85
# total_cost: 20557894.24
# total_trades: 18360
# Sharpe: 0.053
# =================================
# Logging Error: name 'statistics' is not defined
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 16           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0075076646 |
# |    clip_fraction        | 0.0691       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -17.2        |
# |    explained_variance   | -0.00592     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.18e+05     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0143      |
# |    reward               | -60.68227    |
# |    reward_max           | None         |
# |    reward_mean          | None         |
# |    reward_min           | None         |
# |    std                  | 1.02         |
# |    value_loss           | 5.04e+05     |
# ------------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 17          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010756971 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.2       |
# |    explained_variance   | -0.000773   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.32e+04    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0179     |
# |    reward               | 292.842     |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.02        |
# |    value_loss           | 1.15e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 18          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008043638 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.3       |
# |    explained_variance   | 0.0025      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.51e+04    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0129     |
# |    reward               | 54.32581    |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.02        |
# |    value_loss           | 2.2e+05     |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 19          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008940759 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.3       |
# |    explained_variance   | 0.000757    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.83e+04    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0186     |
# |    reward               | 69.54449    |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.02        |
# |    value_loss           | 2.67e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 20          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010710092 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.3       |
# |    explained_variance   | -0.00264    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.31e+05    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0177     |
# |    reward               | -37.582516  |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.03        |
# |    value_loss           | 2.65e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 21          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012259988 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.4       |
# |    explained_variance   | -0.000478   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.37e+05    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0182     |
# |    reward               | 84.606606   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.03        |
# |    value_loss           | 2.54e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 22           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0112755345 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -17.4        |
# |    explained_variance   | -0.000713    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.35e+04     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0218      |
# |    reward               | 81.949615    |
# |    reward_max           | None         |
# |    reward_mean          | None         |
# |    reward_min           | None         |
# |    std                  | 1.04         |
# |    value_loss           | 2.31e+05     |
# ------------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 23          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009225544 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.4       |
# |    explained_variance   | 0.000603    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.63e+05    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0175     |
# |    reward               | -1067.7672  |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.04        |
# |    value_loss           | 4.94e+05    |
# -----------------------------------------
# day: 1688, episode: 90
# begin_total_asset: 100000000.00
# end_total_asset: 226681194.57
# total_reward: 126681194.57
# total_cost: 23131805.47
# total_trades: 18879
# Sharpe: 0.762
# =================================
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 24          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009587914 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.5       |
# |    explained_variance   | -0.000937   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.6e+05     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.019      |
# |    reward               | 44.001507   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.04        |
# |    value_loss           | 3.53e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 25          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010287424 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.5       |
# |    explained_variance   | -0.000153   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.06e+05    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0134     |
# |    reward               | 166.94553   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.04        |
# |    value_loss           | 4.22e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 26          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010739359 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.5       |
# |    explained_variance   | -0.000325   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.86e+05    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0187     |
# |    reward               | 60.973488   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.04        |
# |    value_loss           | 3.24e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 27          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008243388 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.5       |
# |    explained_variance   | 0.00102     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.03e+05    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0182     |
# |    reward               | -95.13283   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.04        |
# |    value_loss           | 4.47e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 28          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008524842 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.5       |
# |    explained_variance   | -0.00123    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.27e+05    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0146     |
# |    reward               | -5.808996   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.04        |
# |    value_loss           | 6.67e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 29          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011396069 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.5       |
# |    explained_variance   | 4.26e-05    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.14e+05    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0198     |
# |    reward               | 39.792484   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.04        |
# |    value_loss           | 4.11e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 30          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009451054 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.5       |
# |    explained_variance   | -0.00046    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.59e+05    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0175     |
# |    reward               | 200.45013   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.05        |
# |    value_loss           | 5.43e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 302          |
# |    iterations           | 31           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0081632845 |
# |    clip_fraction        | 0.0679       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -17.6        |
# |    explained_variance   | -0.000385    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.38e+05     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.013       |
# |    reward               | 204.1049     |
# |    reward_max           | None         |
# |    reward_mean          | None         |
# |    reward_min           | None         |
# |    std                  | 1.05         |
# |    value_loss           | 4.75e+05     |
# ------------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 32          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011443969 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.6       |
# |    explained_variance   | 0.00015     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.36e+05    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0191     |
# |    reward               | -134.79092  |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.05        |
# |    value_loss           | 6.54e+05    |
# -----------------------------------------
# day: 1688, episode: 100
# begin_total_asset: 100000000.00
# end_total_asset: 120683716.99
# total_reward: 20683716.99
# total_cost: 17831576.26
# total_trades: 17606
# Sharpe: 0.243
# =================================
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 33          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011447034 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.6       |
# |    explained_variance   | -6.35e-05   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.02e+05    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0171     |
# |    reward               | -21.777386  |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.05        |
# |    value_loss           | 2.52e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 34          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.011970457 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.7       |
# |    explained_variance   | -0.00243    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.94e+05    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0174     |
# |    reward               | 97.84898    |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.06        |
# |    value_loss           | 3.76e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 35          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012531692 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.7       |
# |    explained_variance   | -0.00092    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1e+05       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0168     |
# |    reward               | -240.52568  |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.06        |
# |    value_loss           | 3.27e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 36          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009359472 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.7       |
# |    explained_variance   | -0.00017    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.56e+05    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0153     |
# |    reward               | -2.6542017  |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.06        |
# |    value_loss           | 4.78e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 37          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010743532 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.7       |
# |    explained_variance   | 0.000209    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.14e+05    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0193     |
# |    reward               | 41.046917   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.06        |
# |    value_loss           | 4.15e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 300        |
# |    iterations           | 38         |
# |    time_elapsed         | 258        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01385371 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -17.8      |
# |    explained_variance   | -0.000134  |
# |    learning_rate        | 0.00025    |
# |    loss                 | 9.51e+04   |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0208    |
# |    reward               | -42.709297 |
# |    reward_max           | None       |
# |    reward_mean          | None       |
# |    reward_min           | None       |
# |    std                  | 1.07       |
# |    value_loss           | 3.6e+05    |
# ----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 39          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.012497642 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.8       |
# |    explained_variance   | -0.000195   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.28e+05    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0196     |
# |    reward               | 24.340685   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.07        |
# |    value_loss           | 3.74e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 40          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011881507 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.9       |
# |    explained_variance   | -0.000172   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.31e+05    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0206     |
# |    reward               | -73.21887   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.08        |
# |    value_loss           | 3.25e+05    |
# -----------------------------------------
# day: 1688, episode: 110
# begin_total_asset: 100000000.00
# end_total_asset: 293858241.20
# total_reward: 193858241.20
# total_cost: 19986776.43
# total_trades: 18104
# Sharpe: 0.963
# =================================
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 41          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.007762082 |
# |    clip_fraction        | 0.0717      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.9       |
# |    explained_variance   | 0.00102     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.45e+05    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0124     |
# |    reward               | 74.62131    |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.08        |
# |    value_loss           | 3.01e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 301        |
# |    iterations           | 42         |
# |    time_elapsed         | 285        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01350102 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18        |
# |    explained_variance   | 0.000531   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 5.18e+05   |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00949   |
# |    reward               | -497.31082 |
# |    reward_max           | None       |
# |    reward_mean          | None       |
# |    reward_min           | None       |
# |    std                  | 1.08       |
# |    value_loss           | 6.7e+05    |
# ----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 43          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.012060931 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18         |
# |    explained_variance   | 6.08e-06    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.72e+04    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.011      |
# |    reward               | 16.643343   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.09        |
# |    value_loss           | 2.54e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 44          |
# |    time_elapsed         | 298         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009243634 |
# |    clip_fraction        | 0.0927      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18         |
# |    explained_variance   | 0.000237    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.06e+05    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0163     |
# |    reward               | -44.885902  |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.09        |
# |    value_loss           | 2.52e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 45          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010766694 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.1       |
# |    explained_variance   | -8.34e-05   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.45e+05    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0181     |
# |    reward               | -170.20883  |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.09        |
# |    value_loss           | 3.28e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 46          |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011445429 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.1       |
# |    explained_variance   | -0.000534   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.51e+05    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0198     |
# |    reward               | 96.3566     |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.09        |
# |    value_loss           | 4.75e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 47          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010014091 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.1       |
# |    explained_variance   | 0.000307    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.07e+05    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0149     |
# |    reward               | 406.36145   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.09        |
# |    value_loss           | 4.57e+05    |
# -----------------------------------------
# Logging Error: name 'statistics' is not defined
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 48           |
# |    time_elapsed         | 325          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0085080005 |
# |    clip_fraction        | 0.083        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -18.1        |
# |    explained_variance   | -0.00188     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.59e+05     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0126      |
# |    reward               | 228.56772    |
# |    reward_max           | None         |
# |    reward_mean          | None         |
# |    reward_min           | None         |
# |    std                  | 1.1          |
# |    value_loss           | 5.2e+05      |
# ------------------------------------------
# day: 1688, episode: 120
# begin_total_asset: 100000000.00
# end_total_asset: 243008086.09
# total_reward: 143008086.09
# total_cost: 18201458.46
# total_trades: 17562
# Sharpe: 0.813
# =================================
# Logging Error: name 'statistics' is not defined
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 49          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.013389273 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.1       |
# |    explained_variance   | 0.000237    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.34e+05    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0238     |
# |    reward               | 102.13334   |
# |    reward_max           | None        |
# |    reward_mean          | None        |
# |    reward_min           | None        |
# |    std                  | 1.1         |
# |    value_loss           | 3.15e+05    |
# -----------------------------------------

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 SAC_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  60.29836065156226
# ======Model training from:  2014-01-01 to  2020-10-01 00:00:00
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_9
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 100        |
# |    time_elapsed       | 2          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -16.9      |
# |    explained_variance | 0.000232   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -757       |
# |    reward             | -209.44049 |
# |    reward_max         | None       |
# |    reward_mean        | None       |
# |    reward_min         | None       |
# |    std                | 0.993      |
# |    value_loss         | 1.42e+04   |
# --------------------------------------
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# -------------------------------------
# | time/                 |           |
# |    fps                | 218       |
# |    iterations         | 200       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -16.9     |
# |    explained_variance | -0.000307 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | 6.36e+03  |
# |    reward             | 911.7352  |
# |    reward_max         | None      |
# |    reward_mean        | None      |
# |    reward_min         | None      |
# |    std                | 0.992     |
# |    value_loss         | 2.11e+05  |
# -------------------------------------
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# --------------------------------------
# | time/                 |            |
# |    fps                | 189        |
# |    iterations         | 300        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -17        |
# |    explained_variance | 0.0294     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | 236        |
# |    reward             | -172.87897 |
# |    reward_max         | None       |
# |    reward_mean        | None       |
# |    reward_min         | None       |
# |    std                | 0.995      |
# |    value_loss         | 8.93e+03   |
# --------------------------------------
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# --------------------------------------
# | time/                 |            |
# |    fps                | 172        |
# |    iterations         | 400        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -16.9      |
# |    explained_variance | 4.38e-05   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 3.18e+03   |
# |    reward             | -62.770348 |
# |    reward_max         | None       |
# |    reward_mean        | None       |
# |    reward_min         | None       |
# |    std                | 0.993      |
# |    value_loss         | 4.95e+04   |
# --------------------------------------
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# --------------------------------------
# | time/                 |            |
# |    fps                | 165        |
# |    iterations         | 500        |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -16.9      |
# |    explained_variance | 2.98e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -3.91e+03  |
# |    reward             | -72.625275 |
# |    reward_max         | None       |
# |    reward_mean        | None       |
# |    reward_min         | None       |
# |    std                | 0.992      |
# |    value_loss         | 5.05e+04   |
# --------------------------------------
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# -------------------------------------
# | time/                 |           |
# |    fps                | 169       |
# |    iterations         | 600       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -16.9     |
# |    explained_variance | 0.00805   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -1.78e+03 |
# |    reward             | -338.6625 |
# |    reward_max         | None      |
# |    reward_mean        | None      |
# |    reward_min         | None      |
# |    std                | 0.991     |
# |    value_loss         | 2.04e+04  |
# -------------------------------------
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# --------------------------------------
# | time/                 |            |
# |    fps                | 174        |
# |    iterations         | 700        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -16.9      |
# |    explained_variance | 0.0251     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | 6.72e+03   |
# |    reward             | -129.49144 |
# |    reward_max         | None       |
# |    reward_mean        | None       |
# |    reward_min         | None       |
# |    std                | 0.993      |
# |    value_loss         | 1.44e+05   |
# --------------------------------------
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# -------------------------------------
# | time/                 |           |
# |    fps                | 177       |
# |    iterations         | 800       |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -16.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -3.66e+03 |
# |    reward             | -84.15158 |
# |    reward_max         | None      |
# |    reward_mean        | None      |
# |    reward_min         | None      |
# |    std                | 0.992     |
# |    value_loss         | 9.45e+04  |
# -------------------------------------
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# -------------------------------------
# | time/                 |           |
# |    fps                | 166       |
# |    iterations         | 900       |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -16.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 7.61e+03  |
# |    reward             | 118.70741 |
# |    reward_max         | None      |
# |    reward_mean        | None      |
# |    reward_min         | None      |
# |    std                | 0.992     |
# |    value_loss         | 4.48e+05  |
# -------------------------------------
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined
# -------------------------------------
# | time/                 |           |
# |    fps                | 158       |
# |    iterations         | 1000      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -16.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -1.25e+03 |
# |    reward             | 854.13477 |
# |    reward_max         | None      |
# |    reward_mean        | None      |
# |    reward_min         | None      |
# |    std                | 0.991     |
# |    value_loss         | 1.46e+04  |
# -------------------------------------
# Logging Error: name 'statistics' is not defined
# Logging Error: name 'statistics' is not defined

# %% [markdown]
# ### Model trading

# %%
train_turbulence = processed[(processed.date >= TRAIN_START_DATE) & (processed.date < TRAIN_END_DATE)]
turbulence_threshold = np.quantile(train_turbulence.turbulence.values, 0.90)
print(f"Calculated turbulence threshold: {turbulence_threshold}")

# %%
print("==============Start Trading A2C===========")
e_trade_gym_a2c = StockTradingEnv(
    df=trade, turbulence_threshold=turbulence_threshold, **trading_env_kwargs)

df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_a2c, environment=e_trade_gym_a2c
)
df_account_value_a2c.to_csv("./" + RESULTS_DIR + "/df_account_value_a2c.csv")
df_actions_a2c.to_csv("./" + RESULTS_DIR + "/df_actions_a2c.csv")

# %%
print("==============Start Trading PPO===========")
e_trade_gym_ppo = StockTradingEnv(
    df=trade, turbulence_threshold=turbulence_threshold, **trading_env_kwargs)

df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo, environment=e_trade_gym_ppo  
)
df_account_value_ppo.to_csv("./" + RESULTS_DIR + "/df_account_value_ppo.csv")  
df_actions_ppo.to_csv("./" + RESULTS_DIR + "/df_actions_ppo.csv")
